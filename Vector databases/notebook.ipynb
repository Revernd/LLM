# %% [markdown]
# ## Preparation

# %%
# !pip install -U weaviate-client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting weaviate-client
#   Downloading weaviate_client-4.7.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in /usr/local/lib/python3.8/dist-packages (from weaviate-client) (2.31.0)
# Requirement already satisfied: httpx<=0.27.0,>=0.25.0 in /usr/local/lib/python3.8/dist-packages (from weaviate-client) (0.27.0)
# Collecting validators==0.33.0 (from weaviate-client)
#   Downloading validators-0.33.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting authlib<2.0.0,>=1.2.1 (from weaviate-client)
#   Downloading Authlib-1.3.2-py2.py3-none-any.whl.metadata (3.9 kB)
# Collecting pydantic<3.0.0,>=2.5.0 (from weaviate-client)
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Collecting grpcio<2.0.0,>=1.57.0 (from weaviate-client)
#   Downloading grpcio-1.66.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting grpcio-tools<2.0.0,>=1.57.0 (from weaviate-client)
#   Downloading grpcio_tools-1.66.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.3 kB)
# Collecting grpcio-health-checking<2.0.0,>=1.57.0 (from weaviate-client)
#   Downloading grpcio_health_checking-1.66.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.8/dist-packages (from authlib<2.0.0,>=1.2.1->weaviate-client) (37.0.4)
# Collecting protobuf<6.0dev,>=5.26.1 (from grpcio-health-checking<2.0.0,>=1.57.0->weaviate-client)
#   Downloading protobuf-5.27.4-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from grpcio-tools<2.0.0,>=1.57.0->weaviate-client) (65.6.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.8/dist-packages (from httpx<=0.27.0,>=0.25.0->weaviate-client) (3.6.1)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<=0.27.0,>=0.25.0->weaviate-client) (2019.11.28)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.8/dist-packages (from httpx<=0.27.0,>=0.25.0->weaviate-client) (1.0.5)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx<=0.27.0,>=0.25.0->weaviate-client) (2.8)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.8/dist-packages (from httpx<=0.27.0,>=0.25.0->weaviate-client) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.8/dist-packages (from httpcore==1.*->httpx<=0.27.0,>=0.25.0->weaviate-client) (0.14.0)
# Collecting annotated-types>=0.4.0 (from pydantic<3.0.0,>=2.5.0->weaviate-client)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic<3.0.0,>=2.5.0->weaviate-client)
#   Downloading pydantic_core-2.20.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.8/dist-packages (from pydantic<3.0.0,>=2.5.0->weaviate-client) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.30.0->weaviate-client) (2.0.12)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.30.0->weaviate-client) (1.25.8)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography->authlib<2.0.0,>=1.2.1->weaviate-client) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography->authlib<2.0.0,>=1.2.1->weaviate-client) (2.21)
# Downloading weaviate_client-4.7.1-py3-none-any.whl (368 kB)
# Downloading validators-0.33.0-py3-none-any.whl (43 kB)
# Downloading Authlib-1.3.2-py2.py3-none-any.whl (225 kB)
# Downloading grpcio-1.66.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 101.5 MB/s eta 0:00:00
# Downloading grpcio_health_checking-1.66.0-py3-none-any.whl (18 kB)
# Downloading grpcio_tools-1.66.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 94.0 MB/s eta 0:00:00
# Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
# Downloading pydantic_core-2.20.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 83.7 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading protobuf-5.27.4-cp38-abi3-manylinux2014_x86_64.whl (309 kB)
# Installing collected packages: validators, pydantic-core, protobuf, grpcio, annotated-types, pydantic, grpcio-tools, grpcio-health-checking, authlib, weaviate-client
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# googleapis-common-protos 1.56.4 requires protobuf<5.0.0dev,>=3.15.0, but you have protobuf 5.27.4 which is incompatible.
# mlflow 2.8.1 requires protobuf<5,>=3.12.0, but you have protobuf 5.27.4 which is incompatible.
# tensorboard 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 5.27.4 which is incompatible.
# tensorflow-cpu 2.9.3 requires protobuf<3.20,>=3.9.2, but you have protobuf 5.27.4 which is incompatible.
# web3 5.31.0 requires protobuf<4,>=3.10.0, but you have protobuf 5.27.4 which is incompatible.
# Successfully installed annotated-types-0.7.0 authlib-1.3.2 grpcio-1.66.0 grpcio-health-checking-1.66.0 grpcio-tools-1.66.0 protobuf-5.27.4 pydantic-2.8.2 pydantic-core-2.20.1 validators-0.33.0 weaviate-client-4.7.1

# %% [markdown]
# ### Get the data

# %% [markdown]
# We'll use a subset of the Jeopardy! quiz dataset:
# https://raw.githubusercontent.com/databyjp/wv_demo_uploader/main/weaviate_datasets/data/jeopardy_1k.json

# %%
import requests
import json

def load_data():
    with open("jeopardy_1k.json", "r") as f:
        raw_data = f.read()
    return raw_data

def download_data():
    response = requests.get('https://raw.githubusercontent.com/databyjp/wv_demo_uploader/main/weaviate_datasets/data/jeopardy_1k.json')
    raw_data = response.text
    return raw_data

# Parse the JSON and preview it
json_data = load_data()
data = json.loads(json_data)
print(type(data), len(data))
print(json.dumps(data[0], indent=2))
# Out:
# <class 'list'> 1000
# {
#   "Air Date": "2006-11-08",
#   "Round": "Double Jeopardy!",
#   "Value": 800,
#   "Category": "AMERICAN HISTORY",
#   "Question": "Abraham Lincoln died across the street from this theatre on April 15, 1865",
#   "Answer": "Ford's Theatre (the Ford Theatre accepted)"
# }

# %% [markdown]
# ## Step 1: Create a Weaviate instance (database)

# %% [markdown]
# We'll use Embedded Weaviate - this is a quick way to create a Weaviate database.
#
# > You can also use:
# > - A free sandbox with Weaviate Cloud Services
# > - Open-source Weaviate directly, available cross-platform with Docker
# > - Or use Kubernetes in production :)

# %%
openai_key = "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"

# %%
import weaviate

client = weaviate.Client(
    embedded_options=weaviate.EmbeddedOptions(),
    additional_headers={
        "X-OpenAI-Api-Key": openai_key
    }
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import weaviate
#       3 client = weaviate.Client(
#       4     embedded_options=weaviate.EmbeddedOptions(),
#       5     additional_headers={
#       6         "X-OpenAI-Api-Key": openai_key
#       7     }
#       8 )
#
# File ~/.local/lib/python3.8/site-packages/weaviate/__init__.py:14
#      11 except PackageNotFoundError:
#      12     __version__ = "unknown version"
# ---> 14 from .client import Client, WeaviateAsyncClient, WeaviateClient
#      15 from .collections.batch.client import BatchClient, ClientBatchingContextManager
#      16 from .connect.helpers import (
#      17     connect_to_custom,
#      18     connect_to_embedded,
#    (...)
#      25     use_async_with_weaviate_cloud,
#      26 )
#
# File ~/.local/lib/python3.8/site-packages/weaviate/client.py:10
#       7 from httpx import HTTPError as HttpxError
#       8 from requests.exceptions import ConnectionError as RequestsConnectionError
# ---> 10 from weaviate.backup.backup import _BackupAsync
#      11 from weaviate.backup.sync import _Backup
#      14 from weaviate import syncify
#
# File ~/.local/lib/python3.8/site-packages/weaviate/backup/__init__.py:7
#       1 """
#       2 Module for backup/restore operations
#       3 """
#       5 __all__ = ["Backup", "BackupStorage"]
# ----> 7 from weaviate.backup.backup import Backup
#       8 from weaviate.backup.backup import BackupStorage
#
# File ~/.local/lib/python3.8/site-packages/weaviate/backup/backup.py:12
#       8 from pydantic import BaseModel, Field
#      10 from requests.exceptions import ConnectionError as RequestsConnectionError
# ---> 12 from weaviate.connect import Connection, ConnectionV4
#      13 from weaviate.exceptions import (
#      14     WeaviateInvalidInputError,
#      15     WeaviateUnsupportedFeatureError,
#      16     BackupFailedException,
#      17     EmptyResponseException,
#      18 )
#      19 from weaviate.util import _capitalize_first_letter, _decode_json_response_dict
#
# File ~/.local/lib/python3.8/site-packages/weaviate/connect/__init__.py:7
#       1 """
#       2 Module communication to a Weaviate instance. Used to connect to
#       3 Weaviate and run REST requests.
#       4 """
#       6 from .base import ConnectionParams, ProtocolParams
# ----> 7 from .v3 import Connection
#       8 from .v4 import ConnectionV4
#      10 __all__ = [
#      11     "Connection",
#      12     "ConnectionParams",
#      13     "ConnectionV4",
#      14     "ProtocolParams",
#      15 ]
#
# File ~/.local/lib/python3.8/site-packages/weaviate/connect/v3.py:43
#      40 from .base import _ConnectionBase, _get_proxies
#      42 import grpc  # type: ignore
# ---> 43 from weaviate.proto.v1 import weaviate_pb2_grpc
#      46 JSONPayload = Union[dict, list]
#      47 Session = Union[requests.sessions.Session, OAuth2Session]
#
# File ~/.local/lib/python3.8/site-packages/weaviate/proto/v1/weaviate_pb2_grpc.py:5
#       2 """Client and server classes corresponding to protobuf-defined services."""
#       3 import grpc
# ----> 5 from weaviate.proto.v1 import batch_delete_pb2 as v1_dot_batch__delete__pb2
#       6 from weaviate.proto.v1 import batch_pb2 as v1_dot_batch__pb2
#       7 from weaviate.proto.v1 import search_get_pb2 as v1_dot_search__get__pb2
#
# File ~/.local/lib/python3.8/site-packages/weaviate/proto/v1/batch_delete_pb2.py:9
#       7 from google.protobuf import descriptor_pool as _descriptor_pool
#       8 from google.protobuf import symbol_database as _symbol_database
# ----> 9 from google.protobuf.internal import builder as _builder
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
#
# ImportError: cannot import name 'builder' from 'google.protobuf.internal' (/usr/local/lib/python3.8/dist-packages/google/protobuf/internal/__init__.py)

# %%
def jprint(data_in):
    print(json.dumps(data_in, indent=2))

# %% [markdown]
# Retrieve Weaviate instance information to check our configuration.

# %%
jprint(client.get_meta())
# Out:
# {
#   "hostname": "http://127.0.0.1:6666",
#   "modules": {
#     "generative-openai": {
#       "documentationHref": "https://beta.openai.com/docs/api-reference/completions",
#       "name": "Generative Search - OpenAI"
#     },
#     "qna-openai": {
#       "documentationHref": "https://beta.openai.com/docs/api-reference/completions",
#       "name": "OpenAI Question & Answering Module"
#     },
#     "ref2vec-centroid": {},
#     "text2vec-cohere": {
#       "documentationHref": "https://docs.cohere.ai/embedding-wiki/",
#       "name": "Cohere Module"
#     },
#     "text2vec-huggingface": {
#       "documentationHref": "https://huggingface.co/docs/api-inference/detailed_parameters#feature-extraction-task",
#       "name": "Hugging Face Module"
#     },
#     "text2vec-openai": {
#       "documentationHref": "https://beta.openai.com/docs/guides/embeddings/what-are-embeddings",
#       "name": "OpenAI Module"
#     }
#   },
#   "version": "1.19.12"
# }

# %% [markdown]
# ## Step 2: Add data to Weaviate

# %% [markdown]
# ### Add class definition

# %% [markdown]
# The equivalent of a SQL "table", or noSQL "collection" is called a "class" in Weaviate.

# %% [markdown]
# #### Delete existing data

# %% [markdown]
# In case I created a demo class - let's delete it.

# %%
if client.schema.exists("Question"):
    client.schema.delete_class("Question")

# %% [markdown]
# And create a new class definition here.
# We'll set up a class called "Question" with:
# - A "vectorizer" -> which will convert data to vectors, which represent meaning,
# - A "generative" module -> which will allow us to use LLMs with our data, and
# - Properties to save our quiz data (which are like SQL columns).
#     - Just the question and answer for now

# %% [markdown]
# #### Tip

# %% [markdown]
# > You can get example class definitions in our documentation:
# > - https://weaviate.io/developers/weaviate/manage-data/classes#example-class-configurations

# %%
class_definition = {
    "class": "Question",
    "vectorizer": "text2vec-openai",
    "vectorIndexConfig": {
        "distance": "cosine",
    },
    "moduleConfig": {
        "generative-cohere": {}
    },
    "properties": [
        {
            "name": "question",
            "dataType": ["text"]
        },
        {
            "name": "answer",
            "dataType": ["text"]
        },
    ],
}

client.schema.create_class(class_definition)
# Out:
# {"action":"hnsw_vector_cache_prefill","count":1000,"index_id":"question_vNYIGrAhRBdl","level":"info","limit":1000000000000,"msg":"prefilled vector cache","time":"2023-08-15T15:16:49Z","took":33092}

# %% [markdown]
# Was our class created successfully? Let's take a look

# %%
jprint(client.schema.get("Question"))
# Out:
# {
#   "class": "Question",
#   "invertedIndexConfig": {
#     "bm25": {
#       "b": 0.75,
#       "k1": 1.2
#     },
#     "cleanupIntervalSeconds": 60,
#     "stopwords": {
#       "additions": null,
#       "preset": "en",
#       "removals": null
#     }
#   },
#   "moduleConfig": {
#     "generative-openai": {},
#     "text2vec-openai": {
#       "model": "ada",
#       "modelVersion": "002",
#       "type": "text",
#       "vectorizeClassName": true
#     }
#   },
#   "properties": [
#     {
#       "dataType": [
#         "text"
#       ],
#       "indexFilterable": true,
#       "indexSearchable": true,
#       "moduleConfig": {
#         "text2vec-openai": {
#           "skip": false,
#           "vectorizePropertyName": false
#         }
#       },
#       "name": "question",
#       "tokenization": "word"
#     },
#     {
#       "dataType": [
#         "text"
#       ],
#       "indexFilterable": true,
#       "indexSearchable": true,
#       "moduleConfig": {
#         "text2vec-openai": {
#           "skip": false,
#           "vectorizePropertyName": false
#         }
#       },
#       "name": "answer",
#       "tokenization": "word"
#     }
#   ],
#   "replicationConfig": {
#     "factor": 1
#   },
#   "shardingConfig": {
#     "virtualPerPhysical": 128,
#     "desiredCount": 1,
#     "actualCount": 1,
#     "desiredVirtualCount": 128,
#     "actualVirtualCount": 128,
#     "key": "_id",
#     "strategy": "hash",
#     "function": "murmur3"
#   },
#   "vectorIndexConfig": {
#     "skip": false,
#     "cleanupIntervalSeconds": 300,
#     "maxConnections": 64,
#     "efConstruction": 128,
#     "ef": -1,
#     "dynamicEfMin": 100,
#     "dynamicEfMax": 500,
#     "dynamicEfFactor": 8,
#     "vectorCacheMaxObjects": 1000000000000,
#     "flatSearchCutoff": 40000,
#     "distance": "cosine",
#     "pq": {
#       "enabled": false,
#       "bitCompression": false,
#       "segments": 0,
#       "centroids": 256,
#       "encoder": {
#         "type": "kmeans",
#         "distribution": "log-normal"
#       }
#     }
#   },
#   "vectorIndexType": "hnsw",
#   "vectorizer": "text2vec-openai"
# }

# %% [markdown]
# ### Add data

# %% [markdown]
# We'll add actual objects (SQL rows) to our data.
#
# First, let's build objects to add - and take a look at a couple.

# %%
for row in data[:2]:
    data_obj = {
        "question": row["Question"],
        "answer": row["Answer"]
    }
    print(data_obj)
# Out:
# {'question': 'Abraham Lincoln died across the street from this theatre on April 15, 1865', 'answer': "Ford's Theatre (the Ford Theatre accepted)"}
# {'question': 'Any pigment on the wall so faded you can barely see it', 'answer': 'faint paint'}

# %% [markdown]
# > If it all looks fine - let's add objects:
# > - https://weaviate.io/developers/weaviate/manage-data/import

# %%
with client.batch() as batch:
    for row in data:
        data_obj = {
            "question": row["Question"],
            "answer": row["Answer"]
        }
        batch.add_data_object(
            data_object=data_obj,
            class_name="Question"
        )

# %%
len(data)
# Out:
# 1000

# %% [markdown]
# #### Confirm data load

# %% [markdown]
# Do we have data?
#
# Let's get an object count

# %%
client.query.aggregate("Question").with_meta_count().do()
# Out:
# {'data': {'Aggregate': {'Question': [{'meta': {'count': 1000}}]}}}

# %% [markdown]
# Does the data look right?
#
# Let's grab a few objects from Weaviate!

# %%
response = (
    client.query
    .get("Question", ["question", "answer"])
    .with_limit(3)
    .do()
)

jprint(response)
# Out:
# {
#   "data": {
#     "Get": {
#       "Question": [
#         {
#           "answer": "Adam",
#           "question": "Created from the earth, this man's name in Hebrew means \"red earth\""
#         },
#         {
#           "answer": "buffalo",
#           "question": "Animal that was the main staple of the Plains Indians economy"
#         },
#         {
#           "answer": "Rock Band",
#           "question": "You can form your own rock band & tour the world with this 2007 video game from MTV games"
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# Let's pause for a second - because we've done a lot!

# %% [markdown]
# #### What did we just do?
#
# Here is a conceptual diagram

# %% [markdown]
# ![img](https://github.com/weaviate-tutorials/intro-workshop/blob/main/images/object_import_process_full.png?raw=1)

# %% [markdown]
# ## Step 3: Work with the data

# %% [markdown]
# Let's try a few more involved queries

# %% [markdown]
# ### Filtering (similar to WHERE filter in SQL)

# %% [markdown]
# Let's find objects that meet a particular condition.

# %%
where_filter = {
    "path": ["answer"],
    "operator": "Like",
    "valueText": "*history*"
}

response = (
    client.query
    .get("Question", ["question", "answer"])
    .with_limit(3)
    .with_where(where_filter)
    .do()
)

jprint(response)
# Out:
# {
#   "data": {
#     "Get": {
#       "Question": [
#         {
#           "answer": "\"A Brief History Of Time In A Bottle\"",
#           "question": "Stephen Hawking's 1988 bio of the universe that was a No. 1 hit for Jim Croce"
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# We can also use multiple filters

# %%
where_filter = {
    "operator": "Or",
    "operands": [
        {
            "path": ["answer"],
            "operator": "Like",
            "valueText": "*history*"
        },
        {
            "path": ["question"],
            "operator": "Like",
            "valueText": "*history*"
        },        
    ]
}

response = (
    client.query
    .get("Question", ["question", "answer"])
    .with_limit(3)
    .with_where(where_filter)
    .do()
)

jprint(response)
# Out:
# {
#   "data": {
#     "Get": {
#       "Question": [
#         {
#           "answer": "the Field Museum",
#           "question": "What was once the Chicago Natural History Museum is now called this, after its founder"
#         },
#         {
#           "answer": "Greyhound",
#           "question": "A Hibbing, Minn. museum traces the history of this bus company founded there in 1914 using Hupmobiles"
#         },
#         {
#           "answer": "the draft",
#           "question": "You're in the Army now--in 1940 FDR instituted the first peacetime one of these in U.S. history"
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# But this does not rank the result in any meaningful way.
#
# For that, we need a keyword search (as opposed to a keyword *filter*).

# %% [markdown]
# ### Keyword search

# %% [markdown]
# Unlike a keyword filter, a keyword search will search for, and rank results based on the frequency of the keyword.

# %%
response = (
    client.query
    .get("Question", ["question", "answer"])
    .with_limit(3)
    .with_bm25(query="history")
    .do()
)

jprint(response)
# Out:
# {
#   "data": {
#     "Get": {
#       "Question": [
#         {
#           "answer": "\"A Brief History Of Time In A Bottle\"",
#           "question": "Stephen Hawking's 1988 bio of the universe that was a No. 1 hit for Jim Croce"
#         },
#         {
#           "answer": "Oil",
#           "question": "The Drake Well Museum in Titusville, Penn. is dedicated to the history of this industry"
#         },
#         {
#           "answer": "the Field Museum",
#           "question": "What was once the Chicago Natural History Museum is now called this, after its founder"
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# ### Semantic search

# %% [markdown]
# A semantic search, on the other hand, searches objects based on similarity

# %%
response = (
    client.query
    .get("Question", ["question", "answer"])
    .with_limit(3)
    .with_near_text({"concepts": ["history"]})
    .do()
)

jprint(response)
# Out:
# {
#   "data": {
#     "Get": {
#       "Question": [
#         {
#           "answer": "Greyhound",
#           "question": "A Hibbing, Minn. museum traces the history of this bus company founded there in 1914 using Hupmobiles"
#         },
#         {
#           "answer": "The Rijksmuseum",
#           "question": "This Dutch national art museum had its origins in one founded by Louis Bonaparte in 1808"
#         },
#         {
#           "answer": "Shinto",
#           "question": "Compiled in 712, the Kojiki, \"Records of Ancient Matters\", is one of this religion's oldest texts"
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# #### How does this work?

# %% [markdown]
# - Under the hood, this uses a vector search. It looks for objects which are the most similar to a text input.
# - We can inspect the similarity along with the results.

# %%
response = (
    client.query
    .get("Question", ["question", "answer"])
    .with_limit(3)
    .with_near_text({"concepts": ["history"]})
    .with_additional("distance")
    .do()
)

jprint(response)
# Out:
# {
#   "data": {
#     "Get": {
#       "Question": [
#         {
#           "_additional": {
#             "distance": 0.19912618
#           },
#           "answer": "Greyhound",
#           "question": "A Hibbing, Minn. museum traces the history of this bus company founded there in 1914 using Hupmobiles"
#         },
#         {
#           "_additional": {
#             "distance": 0.20578152
#           },
#           "answer": "The Rijksmuseum",
#           "question": "This Dutch national art museum had its origins in one founded by Louis Bonaparte in 1808"
#         },
#         {
#           "_additional": {
#             "distance": 0.20843762
#           },
#           "answer": "Shinto",
#           "question": "Compiled in 712, the Kojiki, \"Records of Ancient Matters\", is one of this religion's oldest texts"
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# This is where "vectors" come in.
#
# Each object in Weaviate includes a vector - like so:

# %%
response = (
    client.query
    .get("Question", ["question", "answer"])
    .with_limit(3)
    .with_near_text({"concepts": ["history"]})
    .with_additional("vector")
    .do()
)

jprint(response)
# Out:
# {
#   "data": {
#     "Get": {
#       "Question": [
#         {
#           "_additional": {
#             "vector": [
#               -0.018947069,
#               -0.011887303,
#               -0.0006647947,
#               -0.034424767,
#               -0.022093708,
#               0.011335968,
#               0.0020069908,
#               -0.01394472,
#               -0.009177697,
#               -0.031036079,
#               -0.028185278,
#               0.016956888,
#               -0.0030558705,
#               -0.023599792,
#               -0.030820925,
#               0.005439382,
#               0.013171508,
#               0.01306393,
#               0.013010141,
#               0.010609821,
#               -0.008397761,
#               0.0015993734,
#               0.010771187,
#               -0.008424655,
#               0.0010581246,
#               0.0012102458,
#               0.026571618,
#               -0.008888583,
#               -0.0010161021,
#               0.01598869,
#               -0.004740129,
#               -0.0072278567,
#               -0.015813878,
#               -0.0066933315,
#               0.011093919,
#               -0.030202355,
#               0.0075236945,
#               0.011598188,
#               0.019162225,
#               0.009796266,
#               -0.0097290315,
#               -0.0036677169,
#               -0.0070127016,
#               -0.0020473325,
#               -0.0072278567,
#               -0.004138368,
#               0.0033853264,
#               0.00406777,
#               0.0029953583,
#               0.014859128,
#               0.009218038,
#               0.012936182,
#               -0.003993811,
#               -0.015719747,
#               0.020251445,
#               -0.00094466406,
#               0.012505872,
#               0.02698848,
#               -0.016499683,
#               -0.0055637686,
#               0.0085994685,
#               -0.012559662,
#               -0.017951978,
#               0.018678125,
#               -0.016096268,
#               -0.02974515,
#               0.008955819,
#               -0.020587625,
#               0.0100114215,
#               -0.00989712,
#               0.0028239067,
#               0.0069858073,
#               -0.005862968,
#               -0.02170374,
#               0.04112146,
#               -0.025495844,
#               -0.023882182,
#               -0.026114414,
#               -0.0102938125,
#               0.005466277,
#               0.0008782686,
#               -0.022833303,
#               -0.01446916,
#               0.019431168,
#               0.017588904,
#               0.009123908,
#               0.0044409293,
#               0.034236506,
#               0.004561954,
#               0.0016935036,
#               0.010979618,
#               0.014576738,
#               -0.012082286,
#               0.010334154,
#               0.034908865,
#               0.009856779,
#               0.0019918627,
#               0.024863826,
#               0.00063243747,
#               -0.018220922,
#               -0.01366233,
#               0.015208755,
#               0.000659752,
#               -0.01085187,
#               -0.022537464,
#               0.00087490684,
#               0.014966706,
#               -0.016956888,
#               0.0004840983,
#               -0.032488376,
#               0.00417871,
#               0.01656692,
#               0.006279831,
#               -0.024957957,
#               -0.0122369295,
#               -0.021488585,
#               0.015007047,
#               0.001222012,
#               0.02132722,
#               -0.030820925,
#               0.008196053,
#               0.022550913,
#               0.027593603,
#               -0.004609019,
#               0.011793172,
#               0.03402135,
#               -0.03455924,
#               -0.005634366,
#               -0.014886023,
#               0.0065756687,
#               -0.004642637,
#               -0.00028953448,
#               -0.019538745,
#               -0.0029230795,
#               -0.027069163,
#               -0.006252936,
#               -0.022779515,
#               0.040529784,
#               -0.017145148,
#               -0.024433516,
#               0.005230951,
#               0.022120602,
#               -0.0023162758,
#               0.015370121,
#               0.004524974,
#               0.032864895,
#               -0.0031634478,
#               0.013184955,
#               -0.016257634,
#               -0.027001927,
#               0.010320706,
#               -0.0052175038,
#               0.003143277,
#               -0.00828346,
#               0.03264974,
#               0.023182929,
#               0.0029213987,
#               0.008290184,
#               -0.017051017,
#               0.013877484,
#               -0.021730635,
#               0.013554752,
#               0.021717187,
#               0.0074900766,
#               0.015074283,
#               0.031062974,
#               0.0074430113,
#               -0.007913662,
#               0.027970124,
#               -0.012344507,
#               -0.019646322,
#               0.036199793,
#               -0.035392966,
#               -0.0012926097,
#               0.0092718275,
#               0.019861476,
#               0.026504382,
#               0.013890931,
#               -0.045639712,
#               -0.025213452,
#               0.00070723734,
#               0.004205604,
#               0.01780406,
#               0.022913987,
#               0.0157063,
#               0.012048668,
#               0.014159875,
#               -0.021300325,
#               0.01623074,
#               -0.022255074,
#               -0.008626362,
#               0.01030726,
#               0.020775884,
#               0.0041148355,
#               -0.658804,
#               -0.009110461,
#               -0.0009497067,
#               -0.0010396347,
#               -0.008935648,
#               0.0068715066,
#               0.038754757,
#               -0.012768093,
#               -0.02170374,
#               -0.006794185,
#               -0.008707046,
#               0.032730423,
#               0.0043871407,
#               0.013877484,
#               0.0027096057,
#               -0.011362863,
#               0.0032138748,
#               -0.0068009086,
#               0.018678125,
#               0.005836074,
#               -0.0062495745,
#               -0.0026003474,
#               -0.010098828,
#               -0.0015060835,
#               0.02556308,
#               0.009493706,
#               0.00200531,
#               0.0044241208,
#               -0.019242907,
#               -0.010730846,
#               -0.021192748,
#               0.038593393,
#               0.029045898,
#               0.005980631,
#               0.029234158,
#               0.017400645,
#               -0.03351036,
#               0.037329357,
#               0.00498554,
#               0.03784035,
#               -0.0197539,
#               -0.023572898,
#               0.0032004276,
#               0.017898189,
#               0.0071001085,
#               0.024648672,
#               0.014025403,
#               -0.021246536,
#               0.024648672,
#               -0.021340666,
#               0.016472789,
#               0.025307583,
#               -0.005150268,
#               0.02050694,
#               -0.016956888,
#               -0.011383033,
#               0.00070387556,
#               -0.0015060835,
#               -0.0075304178,
#               -0.005718411,
#               -0.0010169426,
#               0.029341735,
#               -0.017763717,
#               -0.00042295567,
#               -0.008095199,
#               0.0083506955,
#               -0.036495633,
#               -0.019000858,
#               0.012761369,
#               -0.025953047,
#               0.0034122206,
#               0.019982502,
#               -0.013769907,
#               0.015208755,
#               0.02056073,
#               0.019995948,
#               0.030390615,
#               -0.007980898,
#               0.00997108,
#               0.02155582,
#               -0.0010598055,
#               -0.006336981,
#               -0.0045384215,
#               -0.011833514,
#               0.049727652,
#               -0.009903844,
#               -0.05620919,
#               -0.007348881,
#               -0.0013052165,
#               -0.001353122,
#               -0.0012245333,
#               -0.002966783,
#               -0.017198937,
#               -0.013729566,
#               -0.008861688,
#               0.026880903,
#               -0.023075351,
#               0.0074362876,
#               0.0042930106,
#               -0.025025193,
#               -0.0044779093,
#               -0.011907473,
#               0.023142587,
#               0.021219643,
#               0.037194885,
#               0.015262543,
#               -0.022537464,
#               -4.850963e-05,
#               0.0046157427,
#               -0.021125512,
#               0.01394472,
#               0.0017330047,
#               -0.03708731,
#               -0.009937462,
#               -0.009547494,
#               -0.030067883,
#               0.026759878,
#               0.00783298,
#               0.0074564586,
#               -0.02365358,
#               -0.0013312703,
#               -0.009883674,
#               -0.0016598856,
#               0.022389546,
#               -0.004400588,
#               -0.002884419,
#               -0.007348881,
#               -0.035339177,
#               -0.020533836,
#               0.013864038,
#               -0.005015796,
#               -0.009365957,
#               0.034424767,
#               -0.0061319117,
#               0.0361729,
#               0.0059570987,
#               0.027916335,
#               -0.010428284,
#               0.01951185,
#               -0.0032054703,
#               -0.032273218,
#               -0.00050258817,
#               -0.002477642,
#               -0.0054797237,
#               0.0023229995,
#               -0.037221782,
#               0.0015682768,
#               -0.006679884,
#               -0.0067336727,
#               0.006178977,
#               -0.0070127016,
#               -0.019915266,
#               -0.020399364,
#               0.019000858,
#               -0.023182929,
#               -0.001360686,
#               -0.023236718,
#               -0.0038694246,
#               0.03412893,
#               -0.013386663,
#               0.004988902,
#               0.009009607,
#               -0.020036291,
#               0.024097336,
#               -0.010024869,
#               -0.031600863,
#               0.019632876,
#               0.039319538,
#               -0.019431168,
#               -0.0014480926,
#               -0.00847172,
#               -0.026289226,
#               -0.0037820179,
#               0.008458273,
#               0.008606192,
#               -0.008155712,
#               0.0020002672,
#               -0.009655071,
#               -4.9691513e-05,
#               -0.016002137,
#               0.007254751,
#               0.0015422229,
#               -0.005879777,
#               0.004518251,
#               0.0093390625,
#               -0.026531275,
#               0.014859128,
#               0.014912917,
#               -0.016889652,
#               0.02123309,
#               -0.00361729,
#               0.013729566,
#               -0.01394472,
#               -0.004185433,
#               -0.030040989,
#               0.01135614,
#               -0.017051017,
#               -0.0013237062,
#               0.020049738,
#               0.023223272,
#               0.016445896,
#               -0.010865318,
#               0.0211793,
#               -0.015760088,
#               -0.002850801,
#               0.00037210854,
#               0.012142799,
#               -0.024756249,
#               0.003923213,
#               0.002282658,
#               0.014132981,
#               -0.0066563515,
#               -0.00909029,
#               -0.033859987,
#               0.019148776,
#               -0.00032315243,
#               -0.008270012,
#               0.016701391,
#               -0.04160556,
#               -0.0037988268,
#               0.018315053,
#               0.017911637,
#               0.020883463,
#               0.004736767,
#               0.0007379137,
#               -0.0021212918,
#               0.021434797,
#               0.021071723,
#               0.015329779,
#               0.006454644,
#               -0.0025331115,
#               0.034155823,
#               -0.0019044562,
#               0.012095734,
#               0.018234368,
#               0.01120822,
#               0.012862223,
#               -0.012485702,
#               0.046043128,
#               0.0028592055,
#               0.02271228,
#               0.0059604603,
#               0.02936863,
#               -0.012344507,
#               -0.0062932777,
#               0.0011707447,
#               0.0071807913,
#               -0.010387942,
#               -0.025361372,
#               0.013971615,
#               -0.031923592,
#               0.0014724657,
#               0.01675518,
#               -0.00091356743,
#               0.0080683045,
#               0.009863502,
#               0.028427327,
#               0.009608006,
#               0.030471299,
#               0.022913987,
#               0.006649628,
#               0.006421026,
#               -0.007200962,
#               -0.02974515,
#               0.003000401,
#               -0.013023589,
#               0.0076648896,
#               0.0016397149,
#               -0.02837354,
#               0.0050124344,
#               -0.025361372,
#               -0.014307794,
#               -0.013837143,
#               -0.036011536,
#               0.022833303,
#               0.017562011,
#               0.0062025096,
#               -0.005449468,
#               0.005328443,
#               0.019807689,
#               -0.01941772,
#               -0.016082821,
#               0.014159875,
#               0.013238744,
#               -0.015598723,
#               -0.0091978675,
#               -0.009883674,
#               0.009473534,
#               -0.019283248,
#               -0.009043225,
#               0.010098828,
#               0.017454432,
#               -0.004565316,
#               0.0026541362,
#               -0.014643974,
#               0.008559126,
#               0.021058276,
#               -0.016728286,
#               0.0013926231,
#               0.009883674,
#               -0.016526578,
#               -0.0073421574,
#               -0.03488197,
#               -0.0008732259,
#               0.027297765,
#               0.0031886613,
#               0.01206884,
#               -0.03203117,
#               -0.003583672,
#               -0.0015279353,
#               0.00088078994,
#               0.0056982404,
#               -0.010804805,
#               -0.0061520827,
#               -0.01746788,
#               0.018933622,
#               -0.015961796,
#               0.016782075,
#               0.054326586,
#               0.008518785,
#               0.0035803104,
#               -0.03165465,
#               -0.030928502,
#               -0.0053015486,
#               0.10940622,
#               0.011463717,
#               -0.015639065,
#               -0.002363341,
#               -0.008666704,
#               0.017965425,
#               -0.012290718,
#               -0.035957746,
#               0.0036609934,
#               0.010764464,
#               0.0035601396,
#               -0.015450804,
#               -0.0015279353,
#               -0.011080472,
#               0.00847172,
#               -0.0074093933,
#               -0.01437503,
#               0.020668307,
#               0.03127813,
#               -0.0010429965,
#               -0.0041988804,
#               -0.011571294,
#               -0.046365857,
#               0.019727005,
#               0.010313983,
#               -0.011423375,
#               0.032165643,
#               0.01135614,
#               -0.00010915324,
#               0.006212595,
#               -0.011934368,
#               0.0041148355,
#               0.008162435,
#               -0.0011614998,
#               0.0021801232,
#               0.013218573,
#               -0.014254006,
#               0.017548563,
#               0.004467824,
#               0.010636715,
#               0.033967562,
#               0.015410462,
#               -0.016835863,
#               -0.0096954135,
#               0.02936863,
#               -0.005704964,
#               0.004871239,
#               0.010300536,
#               0.01030726,
#               -0.01342028,
#               0.04526319,
#               0.0016170228,
#               0.0006942104,
#               -0.0197539,
#               0.01684931,
#               -0.010347601,
#               0.0089154765,
#               -0.0011060302,
#               -0.012109181,
#               -0.004743491,
#               -0.009486982,
#               -0.034451663,
#               0.02494451,
#               -0.014939811,
#               -0.017763717,
#               -0.0299872,
#               -0.03641495,
#               -0.025213452,
#               -0.017346855,
#               0.014092639,
#               -0.0102938125,
#               -0.021878554,
#               0.0025196644,
#               0.028776955,
#               0.03203117,
#               0.015585275,
#               0.019525299,
#               -0.01261345,
#               0.0054024025,
#               0.020493494,
#               0.0054797237,
#               -0.0030861266,
#               -0.0012497468,
#               -0.02099104,
#               0.017158596,
#               0.02151548,
#               0.028669376,
#               -0.004289649,
#               -0.009298721,
#               0.00211793,
#               0.008464997,
#               -0.040207054,
#               0.012714304,
#               -0.009036502,
#               0.011867132,
#               -0.029664468,
#               0.015975244,
#               0.009688689,
#               -0.013917826,
#               0.006256298,
#               0.008975989,
#               0.009325616,
#               0.001450614,
#               -0.022900539,
#               0.005963822,
#               -0.0033634745,
#               0.0055469596,
#               0.005442744,
#               0.0118133435,
#               0.009977804,
#               0.0067403964,
#               -0.018691573,
#               -0.006242851,
#               0.022053367,
#               -0.012250376,
#               0.0034122206,
#               -0.009641624,
#               0.016808968,
#               -0.026746431,
#               -0.015504593,
#               0.0006026015,
#               -0.022591254,
#               0.017642694,
#               0.017642694,
#               -0.02408389,
#               0.006454644,
#               -0.009984528,
#               -0.022954328,
#               -0.03493576,
#               -0.009608006,
#               0.0037853797,
#               0.032165643,
#               -0.003993811,
#               -0.016257634,
#               -0.014173322,
#               -0.013312703,
#               -0.021865107,
#               0.001394304,
#               0.013245467,
#               -0.01118805,
#               -0.0070799375,
#               0.0042829253,
#               0.011699042,
#               0.001677535,
#               0.0008547361,
#               -0.019444615,
#               0.002314595,
#               0.009170974,
#               0.009984528,
#               0.01366233,
#               0.003650908,
#               0.017266173,
#               -0.0053687845,
#               0.00537887,
#               -0.0029533359,
#               -0.020775884,
#               0.0021885277,
#               -0.018597443,
#               0.012472255,
#               0.039050598,
#               0.029287947,
#               0.014509502,
#               0.020143868,
#               0.004551869,
#               -0.00096903706,
#               0.021878554,
#               -0.015827324,
#               0.018812597,
#               -0.015020494,
#               0.006162168,
#               0.000586633,
#               0.016123163,
#               0.01984803,
#               0.009493706,
#               -0.015652511,
#               0.004269478,
#               -0.0008274215,
#               0.013353045,
#               0.003176895,
#               -0.05306255,
#               -0.010764464,
#               0.0053183576,
#               0.0031819378,
#               0.029234158,
#               -0.034720607,
#               -0.001973373,
#               0.01235123,
#               -0.00406777,
#               -0.003946746,
#               -0.011920921,
#               0.02618165,
#               -0.03251527,
#               0.031036079,
#               0.006780738,
#               -0.015518039,
#               -0.0013035355,
#               -0.0075236945,
#               -0.015518039,
#               0.006703417,
#               0.0062932777,
#               0.0047065113,
#               -0.017898189,
#               -0.0020590986,
#               0.002233912,
#               0.007644719,
#               0.00942647,
#               -0.0033348994,
#               -0.037867244,
#               -0.02294088,
#               -0.022967774,
#               -0.02271228,
#               -0.008444826,
#               -0.020883463,
#               -0.0072076856,
#               0.01941772,
#               0.02370737,
#               -0.00038744672,
#               0.00586633,
#               -0.044429466,
#               -0.0143212415,
#               0.0138236955,
#               -0.022080261,
#               0.01818058,
#               0.0034559239,
#               0.03127813,
#               0.035070233,
#               -0.006434473,
#               -0.024379728,
#               0.010058487,
#               -0.010811528,
#               0.00410475,
#               0.010677056,
#               0.009204592,
#               -0.027781863,
#               -0.018772256,
#               0.0015203712,
#               0.013178231,
#               -0.014697762,
#               -0.020708648,
#               0.022739172,
#               0.036576316,
#               -0.0024087252,
#               -0.0011085515,
#               -0.017064465,
#               -0.00361729,
#               0.023572898,
#               0.0063974936,
#               0.016647603,
#               0.0016758542,
#               -0.001808645,
#               -0.012149522,
#               0.022887092,
#               -0.008075029,
#               0.005822627,
#               0.0037719326,
#               -0.019068094,
#               -0.006158806,
#               0.0026675833,
#               -0.00023553567,
#               -0.0012816838,
#               -0.02241644,
#               0.043380585,
#               -0.030498192,
#               0.010340878,
#               0.0073757754,
#               -0.0035500543,
#               0.0011984794,
#               0.00022818174,
#               0.0036643553,
#               0.025643762,
#               -0.001662407,
#               -0.015504593,
#               0.0019767347,
#               0.025267242,
#               0.020036291,
#               -0.0053217197,
#               0.0006017611,
#               -0.0010648482,
#               -0.021461692,
#               -0.024648672,
#               0.019390827,
#               0.015813878,
#               -0.011631806,
#               0.0105425855,
#               0.004736767,
#               -0.0204666,
#               -0.017736824,
#               0.00021788625,
#               0.003079403,
#               -0.030067883,
#               -0.037221782,
#               -0.016217293,
#               0.0021599524,
#               0.008027963,
#               -0.020453153,
#               -0.015128071,
#               0.008834794,
#               0.04908219,
#               -0.008417931,
#               0.016513132,
#               0.0011917559,
#               0.016486237,
#               -0.018960517,
#               -0.0052881017,
#               0.0033819645,
#               -0.037383147,
#               0.0029129942,
#               -0.005442744,
#               -0.027459132,
#               -0.010751016,
#               -0.004696426,
#               0.025872365,
#               0.009924015,
#               -0.013178231,
#               -0.015786983,
#               0.00837759,
#               0.021017935,
#               -0.007073214,
#               -0.030982291,
#               0.038647182,
#               -0.003229003,
#               0.0045552305,
#               0.018960517,
#               -0.002669264,
#               0.03022925,
#               -0.0062764687,
#               0.004040876,
#               -0.00076985074,
#               -0.039185066,
#               -0.024258703,
#               -0.010468625,
#               0.015504593,
#               -0.026477488,
#               0.0012732794,
#               -0.02479659,
#               -0.014509502,
#               -0.013568199,
#               0.0073892227,
#               -0.005856245,
#               0.012647068,
#               0.0098702265,
#               0.013144613,
#               0.013568199,
#               0.028911427,
#               -0.0017145148,
#               0.004908219,
#               0.0064849,
#               -0.012889117,
#               -0.025643762,
#               -0.0071337265,
#               0.002655817,
#               0.054864474,
#               -0.01206884,
#               6.550245e-05,
#               -0.033859987,
#               0.013628712,
#               -0.0380824,
#               -0.0031365536,
#               0.030767135,
#               0.009702137,
#               0.03735625,
#               -0.011335968,
#               -0.017494775,
#               -0.0015539891,
#               -0.003940022,
#               0.020291787,
#               0.018046109,
#               -0.0017380473,
#               -0.0039198515,
#               -0.008949094,
#               0.00211793,
#               0.01770993,
#               -0.004602296,
#               -0.008888583,
#               0.0016128205,
#               -0.004951922,
#               0.00537887,
#               0.029395524,
#               -0.008384313,
#               0.015397015,
#               -0.012082286,
#               -0.0071740677,
#               0.013621988,
#               -0.022160944,
#               0.00901633,
#               -0.015101178,
#               -0.045827974,
#               -0.0070664906,
#               -0.016782075,
#               -0.010972895,
#               -0.01244536,
#               -0.0032710254,
#               0.025764788,
#               0.009379405,
#               -0.019242907,
#               0.0091978675,
#               0.008397761,
#               0.0020103527,
#               0.011309074,
#               -0.0006488262,
#               -0.0064311116,
#               0.017642694,
#               0.016889652,
#               0.010448455,
#               -0.0011606592,
#               0.019740453,
#               -0.020399364,
#               -0.00909029,
#               -0.009628178,
#               -0.044052944,
#               0.0051065646,
#               -0.010172788,
#               0.020453153,
#               -0.021623056,
#               -0.013729566,
#               -0.0102938125,
#               0.0069858073,
#               -0.024769695,
#               0.016499683,
#               -0.020829674,
#               -0.022349205,
#               -0.00521078,
#               -0.004262754,
#               0.021730635,
#               -0.012216758,
#               -0.0058932244,
#               -0.0024725993,
#               -0.029449314,
#               -0.011894026,
#               0.007839703,
#               0.0071135554,
#               -0.030713348,
#               -0.00830363,
#               0.0065117944,
#               -0.0071606208,
#               0.008229671,
#               0.17642693,
#               -0.0068009086,
#               0.022981223,
#               0.007449735,
#               -0.035043336,
#               0.013272362,
#               0.013548029,
#               0.0061520827,
#               0.01684931,
#               0.02132722,
#               -0.013050484,
#               0.00078497885,
#               -0.014509502,
#               -0.0029802301,
#               0.0057453057,
#               -0.045343872,
#               -0.04407984,
#               -0.019552192,
#               -0.03550054,
#               -0.012317612,
#               0.007059767,
#               0.0036744406,
#               0.0073623285,
#               -0.013709395,
#               0.028104596,
#               -0.0011346054,
#               0.0024053634,
#               0.012821881,
#               0.020170763,
#               0.016540024,
#               -0.011551123,
#               -0.021407902,
#               0.006041143,
#               -0.01694344,
#               0.005432659,
#               -0.003423987,
#               0.01171249,
#               -0.020076632,
#               0.0074430113,
#               0.004256031,
#               0.007153897,
#               -0.035769485,
#               -0.008290184,
#               0.0040644086,
#               0.003960193,
#               0.0044543766,
#               0.0028793763,
#               -0.011228391,
#               -0.0032021084,
#               -0.013500963,
#               -0.03980364,
#               -0.027378447,
#               0.005671346,
#               0.029691363,
#               0.004124921,
#               -0.01775027,
#               -0.007550589,
#               0.0015455846,
#               0.0032508546,
#               -0.009332339,
#               -0.013440452,
#               0.029637573,
#               -0.0123781245,
#               0.02541516,
#               -0.008928924,
#               -0.002783565,
#               0.0040207054,
#               0.014697762,
#               0.010071934,
#               -0.018812597,
#               -0.0021784424,
#               0.0018910089,
#               -0.013057207,
#               -0.0057150493,
#               -0.004871239,
#               -0.026006836,
#               0.026786773,
#               0.023048459,
#               0.01294963,
#               0.009345787,
#               -0.02389563,
#               0.018678125,
#               -0.0026474125,
#               0.0075640357,
#               0.008807899,
#               -0.021569269,
#               0.008646534,
#               0.01456329,
#               -0.0065420507,
#               0.001645598,
#               0.0119545385,
#               -0.0075573125,
#               -0.0010471988,
#               -0.016929993,
#               -0.0057486673,
#               0.0017086316,
#               0.020533836,
#               0.04953939,
#               -0.014294347,
#               0.0091642495,
#               -0.012136076,
#               0.004780471,
#               0.003829083,
#               -0.008229671,
#               -0.0089154765,
#               0.011665424,
#               0.0071337265,
#               -0.010260195,
#               -0.020345576,
#               -0.03256906,
#               -0.0069656367,
#               -0.03770588,
#               0.009655071,
#               -0.0038963188,
#               0.0010942639,
#               0.01913533,
#               0.013615265,
#               -0.028561799,
#               0.006585754,
#               0.0024305768,
#               0.0124117425,
#               -0.01242519,
#               0.004713235,
#               0.0039870874,
#               -0.024984851,
#               -0.0014623803,
#               0.0011127538,
#               0.023290507,
#               -0.002607071,
#               -0.03146639,
#               -0.0066899695,
#               -0.011093919,
#               0.019861476,
#               -0.00674712,
#               -0.014953258,
#               0.0002237694,
#               -0.011934368,
#               -0.022833303,
#               -0.030713348,
#               -0.0042156894,
#               0.014657421,
#               -0.013339598,
#               0.0067403964,
#               -0.006720226,
#               0.0101189995,
#               -0.035635013,
#               0.013104272,
#               0.00037505012,
#               -0.027391896,
#               -0.025388267,
#               -0.012196587,
#               -0.004837621,
#               0.0057251346,
#               -0.0087406635,
#               0.03945401,
#               -0.0005689836,
#               -0.004709873,
#               0.024810039,
#               0.005684793,
#               0.007812808,
#               -0.03547365,
#               0.009379405,
#               0.026329568,
#               -0.019821135,
#               -0.021730635,
#               0.0035803104,
#               -0.17244656,
#               0.014818787,
#               0.010159341,
#               -0.0046661696,
#               -0.0113897575,
#               -0.029960306,
#               0.01111409,
#               -0.009534047,
#               -0.008236394,
#               -0.0038189976,
#               0.019323591,
#               -0.01818058,
#               -0.045021143,
#               -0.017293068,
#               0.008397761,
#               -0.010078657,
#               -0.028239068,
#               0.004319905,
#               0.01703757,
#               -0.016916545,
#               0.019269802,
#               -0.015316332,
#               0.02813149,
#               -0.025912706,
#               0.004303096,
#               0.022873644,
#               -0.006068038,
#               -0.006827803,
#               0.011423375,
#               -0.02837354,
#               -0.020923804,
#               0.0051906095,
#               0.0045989337,
#               -0.0040207054,
#               0.011073749,
#               -0.0010530818,
#               -0.021381008,
#               0.004998987,
#               -0.018449524,
#               0.026921244,
#               0.01489947,
#               -0.008222948,
#               0.028776955,
#               -0.002687754,
#               0.0111409845,
#               0.021811318,
#               -0.00603442,
#               0.0065924777,
#               0.03770588,
#               -0.017158596,
#               0.01332615,
#               -0.0238015,
#               0.016311424,
#               0.027526367,
#               -0.013070654,
#               -0.008330525,
#               -0.005627643,
#               0.0022742534,
#               0.008276736,
#               -0.0010698908,
#               -0.018785704,
#               -0.0094466405,
#               0.021434797,
#               -0.01025347,
#               -0.022174392,
#               -0.05163715,
#               -0.02265849,
#               -0.010650163,
#               -0.03184291,
#               0.012398295,
#               -0.020870015,
#               -0.014065745,
#               0.0146708675,
#               -0.012640344,
#               0.020063184,
#               0.010145893,
#               -0.01259328,
#               0.0065891156,
#               -0.020197656,
#               -0.0025986666,
#               -0.018503312,
#               0.057069812,
#               -0.03041751,
#               -0.0018842854,
#               -0.019350484,
#               -0.01851676,
#               0.00635379,
#               0.011873855,
#               -0.007846426,
#               0.004350161,
#               0.00084465067,
#               -0.024742803,
#               0.010347601,
#               -0.027217083,
#               0.011033407,
#               0.005583939,
#               -0.0065218797,
#               -0.019054648,
#               -0.008417931,
#               -0.024258703,
#               -0.011201496,
#               -0.018167133,
#               -0.026867455,
#               0.0011741065,
#               0.032864895,
#               0.024957957,
#               0.0230888,
#               0.009500429,
#               0.03313384,
#               0.015007047,
#               -0.0018120068,
#               0.038593393,
#               0.032327008,
#               0.025119323,
#               -0.009749202,
#               -0.013890931,
#               0.0064008553,
#               -0.027499473,
#               0.0072749215,
#               0.021394456,
#               0.03692594,
#               0.0075371414,
#               -0.0111073665,
#               0.022201287,
#               -0.001263194,
#               -0.023640133,
#               -0.09864847,
#               -0.012290718,
#               0.011006513,
#               -0.014791892,
#               0.0063638757,
#               0.03060577,
#               0.017602352,
#               0.013010141,
#               -0.00511665,
#               0.020170763,
#               -0.02294088,
#               -0.015074283,
#               0.0038963188,
#               -0.017024124,
#               0.066697985,
#               0.027297765,
#               -0.0020927165,
#               -0.0108585935,
#               -0.018543655,
#               0.01990182,
#               -0.011342692,
#               0.0034424767,
#               -0.016795522,
#               0.0013480793,
#               -0.008982712,
#               -0.014724657,
#               -0.02893832,
#               0.023599792,
#               0.025240347,
#               0.0073421574,
#               0.017830953,
#               -0.01566596,
#               0.008760834,
#               0.0006975722,
#               0.0056915167,
#               -0.003390369,
#               -0.014200217,
#               -0.00017292227,
#               0.02037247,
#               -0.019310143,
#               -0.0027112865,
#               0.0045720395,
#               0.015020494,
#               -0.017104806,
#               0.0061554443,
#               -0.033160735,
#               -0.008041411,
#               0.01598869,
#               0.013796802,
#               -0.024783144,
#               -0.014509502,
#               -0.014630526,
#               -0.0068715066,
#               -0.023976313,
#               0.025159664,
#               0.0017514945,
#               0.0020826312,
#               0.018005768,
#               -0.032219432,
#               -0.028427327,
#               0.009365957,
#               -0.008922201,
#               0.0051065646,
#               -0.0035601396,
#               0.0025801766,
#               -0.013379939,
#               -0.007880044,
#               -0.012465531,
#               0.0011278818,
#               -0.021838212,
#               0.011383033,
#               -0.010529138,
#               -0.02127343,
#               -0.003502989,
#               -0.021044828,
#               0.013769907,
#               -0.016674496,
#               -0.008014516,
#               0.006669799,
#               -0.013272362,
#               -0.007550589,
#               -0.011914197,
#               0.010058487,
#               -0.011752831,
#               -0.0069051245,
#               0.014038851,
#               0.005466277,
#               0.016217293,
#               0.01842263,
#               -0.014294347,
#               0.020264892,
#               0.022026472,
#               0.009890397,
#               -0.030820925,
#               0.012176417,
#               0.012405019,
#               0.0041585388,
#               0.021878554,
#               -0.033053156,
#               0.014536396,
#               -0.002686073,
#               -0.011477164,
#               -0.06594495,
#               0.021851659,
#               0.020547284,
#               0.011443546,
#               0.02327706,
#               -0.00066563516,
#               -0.017131701,
#               -0.034209613,
#               0.00078834064,
#               0.015020494,
#               -0.01135614,
#               0.01173266,
#               0.0074900766,
#               -0.007846426,
#               -0.013070654,
#               -0.00942647,
#               0.025213452,
#               -0.02479659,
#               0.00016735429,
#               0.022066815,
#               0.0098702265,
#               0.0041921567,
#               -3.5167515e-05,
#               0.033053156,
#               -0.009513876,
#               -0.00054082857,
#               0.0005185567,
#               0.03308005,
#               0.0036744406,
#               0.008108647,
#               0.02485038,
#               -0.044321887,
#               0.018194027,
#               0.014724657,
#               -0.01627108,
#               -0.009439916,
#               0.002674307,
#               0.0027112865,
#               0.0019515213,
#               0.031385705,
#               -0.015773537,
#               -0.0070328726,
#               0.0025953047,
#               -0.006925295,
#               0.0036744406,
#               -0.01342028,
#               -0.0024994935,
#               0.0071471734,
#               0.019969055,
#               0.014657421,
#               0.016701391,
#               0.02627578,
#               -0.0245142,
#               -0.040018793,
#               0.006847974,
#               0.0118133435,
#               0.0014195174,
#               0.0072749215,
#               -0.0041585388,
#               -0.018126791,
#               0.022160944,
#               0.0046661696,
#               -0.0019296696,
#               0.00046476797,
#               0.03256906,
#               -0.021313772,
#               0.006864783,
#               0.008975989,
#               0.012250376,
#               -0.028346645,
#               -0.016217293,
#               -0.0006093251,
#               0.01660726,
#               -0.004481271,
#               0.011154432,
#               0.0144960545,
#               -0.003160086,
#               -0.01566596,
#               -0.022026472,
#               0.013016866,
#               0.013191679,
#               -0.021394456,
#               -0.00015422229,
#               -0.0066429046,
#               0.044994246,
#               0.018597443,
#               -7.600806e-05,
#               0.022645043,
#               0.012250376,
#               0.010952724,
#               -0.019686664,
#               0.0014027085,
#               -0.0068378886,
#               -0.004551869,
#               -0.023828395,
#               0.007550589,
#               -0.016176952,
#               -0.0015523082,
#               0.008276736,
#               0.028830742,
#               0.0013396748,
#               0.0029768683,
#               0.018382289,
#               -0.039722953,
#               -0.02346532,
#               0.028642483,
#               0.005338528,
#               -0.012512596,
#               0.0034929037,
#               0.020587625,
#               -0.0021044828,
#               0.007691784,
#               -0.0036811642,
#               0.0076312716,
#               -0.007725402,
#               0.021475138,
#               0.008881859,
#               -0.023115695,
#               -0.020668307,
#               0.03259595,
#               0.030390615,
#               0.007321987,
#               0.00028134012,
#               -0.008458273,
#               0.029583784,
#               -0.0018271349,
#               0.02546895,
#               -0.02936863,
#               -0.026289226,
#               0.0083170775,
#               0.011894026,
#               -0.017077912,
#               -0.02198613,
#               -0.00882807,
#               -0.0082095,
#               -0.0091978675,
#               -0.0075640357,
#               0.030525086,
#               -0.006289916,
#               0.076272376,
#               0.0072278567,
#               0.011456993,
#               0.008222948,
#               -0.008041411,
#               0.011006513,
#               0.02661196,
#               -0.0010606459,
#               -0.030874714,
#               0.0011211582,
#               0.018691573,
#               -0.010703951,
#               0.016405553,
#               -0.028104596,
#               -0.013211849,
#               -3.4143217e-05,
#               -0.02327706,
#               0.009789543,
#               0.008343972,
#               -0.00036895685,
#               0.019955607,
#               -0.013487516,
#               0.005916757,
#               0.0016002138,
#               0.009439916,
#               0.007611101,
#               -0.016459342,
#               -0.023949418,
#               -0.034102034,
#               -0.028292855,
#               0.0073085395,
#               0.012290718,
#               -0.030283038,
#               -0.024379728,
#               -0.009117184,
#               -0.01025347,
#               -0.021744082,
#               -0.010408114,
#               0.033752408,
#               -0.027284319,
#               -0.018583996,
#               0.02479659,
#               -0.013104272,
#               0.003634099,
#               0.021246536,
#               -0.01775027,
#               -0.019646322,
#               0.003388688,
#               -0.0019431168
#             ]
#           },
#           "answer": "Greyhound",
#           "question": "A Hibbing, Minn. museum traces the history of this bus company founded there in 1914 using Hupmobiles"
#         },
#         {
#           "_additional": {
#             "vector": [
#               -9.71159e-05,
#               -0.009189146,
#               -0.0058722952,
#               -0.032573756,
#               -0.019293284,
#               0.0020816093,
#               0.010476671,
#               -0.014901317,
#               -0.00050283776,
#               0.0088950405,
#               -0.016914302,
#               0.013084402,
#               -0.0012875261,
#               -0.0060814368,
#               -0.016535234,
#               0.025489096,
#               0.018391361,
#               -0.0041632187,
#               0.0097119985,
#               -0.011541985,
#               -0.0027792917,
#               -0.01065967,
#               -0.008953862,
#               -0.016469877,
#               0.009901533,
#               -0.011796876,
#               0.029541207,
#               -0.04410267,
#               -0.005552048,
#               -0.013332757,
#               -0.0091760745,
#               0.009640106,
#               -0.031188196,
#               -0.019031858,
#               -0.0060487585,
#               -0.0034442956,
#               2.3883262e-05,
#               0.006538933,
#               0.016286878,
#               -4.3017953e-05,
#               0.012221694,
#               0.003244958,
#               -0.001249946,
#               -0.013581113,
#               -0.015855525,
#               -0.009535536,
#               0.016561376,
#               0.013581113,
#               0.01414318,
#               0.012934082,
#               0.0144699635,
#               0.021619981,
#               -0.019162571,
#               -0.0004958936,
#               -0.0123001225,
#               -0.04794564,
#               -0.024195034,
#               0.00535271,
#               -0.017058088,
#               -0.01767244,
#               0.018626647,
#               -0.0065585403,
#               -0.025279954,
#               0.011947196,
#               -0.021306269,
#               -0.027528223,
#               -0.010058389,
#               0.009953818,
#               -0.0042285756,
#               -0.006757878,
#               0.040625695,
#               0.018639717,
#               -0.0077251564,
#               -0.0011388396,
#               0.034351457,
#               0.0024868206,
#               -0.017777009,
#               -7.168808e-05,
#               0.011385129,
#               0.017724724,
#               -0.0023953214,
#               0.0038233642,
#               -0.015986238,
#               0.0152803855,
#               0.014992816,
#               0.018535146,
#               -0.0053232997,
#               0.029619636,
#               0.0010628626,
#               -0.005061873,
#               -0.0009819837,
#               0.025384525,
#               0.0170973,
#               -0.017437154,
#               -0.035893876,
#               -0.0028087022,
#               0.0051501044,
#               0.013182437,
#               -0.0143261785,
#               -0.015110458,
#               0.0037580077,
#               0.0065323976,
#               -0.02673087,
#               -0.031397335,
#               -0.017737797,
#               -0.01375104,
#               -0.007385302,
#               -0.011372058,
#               0.0043004677,
#               0.009346002,
#               0.011868768,
#               0.038769566,
#               0.017358728,
#               -0.039240137,
#               -0.010058389,
#               -0.02956735,
#               0.016286878,
#               0.015986238,
#               0.014548391,
#               -0.030377774,
#               0.0034900452,
#               0.037174866,
#               0.017894652,
#               -0.018182222,
#               0.028077219,
#               0.018051507,
#               -0.035475593,
#               -0.008326437,
#               -0.028730785,
#               -0.0048919455,
#               -0.0001895343,
#               -0.008908112,
#               0.0062807743,
#               -0.00038968906,
#               -0.023711395,
#               0.026796227,
#               -0.016025452,
#               0.013032117,
#               -0.026796227,
#               -0.027737364,
#               0.027868077,
#               0.014914389,
#               -0.0073787663,
#               -0.0036272942,
#               -0.0075486936,
#               0.033724032,
#               -0.007496408,
#               0.01984228,
#               0.004666465,
#               -0.010783847,
#               0.02907064,
#               -0.026848514,
#               0.0045553586,
#               0.0045390194,
#               0.017920794,
#               0.009267573,
#               -0.014639891,
#               0.010620456,
#               -0.0061794715,
#               0.009731606,
#               -0.029750349,
#               0.019410927,
#               0.010522421,
#               0.0037776146,
#               0.017855437,
#               0.035109594,
#               0.022391189,
#               -0.00542787,
#               0.012581156,
#               -0.0017286835,
#               -0.00241983,
#               0.0143261785,
#               -0.036678154,
#               0.0049376953,
#               0.024482602,
#               0.03252147,
#               0.008378723,
#               -0.0035031165,
#               -0.011038739,
#               -0.0038560426,
#               -0.027345223,
#               0.016103879,
#               0.015750954,
#               0.041226976,
#               0.011326308,
#               -0.019384783,
#               0.0017826027,
# ...
#               0.0080346195,
#               0.022230433,
#               -0.019578613,
#               -0.021240948,
#               -0.018773831,
#               -0.0148554705,
#               -0.012045333,
#               0.019380717,
#               -0.019750124,
#               0.011451642,
#               -0.005389396,
#               0.012553268,
#               0.0001605852,
#               0.012883097,
#               -0.0025990477,
#               0.022441523,
#               0.0075002974,
#               -0.0053729047,
#               -0.006075439,
#               -0.01001359,
#               -0.0047792136,
#               -0.0384448,
#               -0.011794663,
#               0.01771838,
#               0.0006250248,
#               0.02263942,
#               0.0060820356,
#               -0.017269814,
#               -0.015950501,
#               -0.0020746207,
#               0.0037897283,
#               0.0041954173,
#               -0.00054339226,
#               -0.004300962,
#               -0.018707866,
#               -0.009499058,
#               0.00051453226,
#               -0.025146117,
#               0.0036775866,
#               0.028074993,
#               0.026742486,
#               0.033536952,
#               -0.022744967,
#               0.011438449,
#               -0.010660053,
#               -0.021913799,
#               -0.00034199082,
#               -0.010191698,
#               0.027230632,
#               -0.031874616,
#               0.011900208,
#               0.003276845,
#               0.027045928,
#               -0.032666203,
#               -0.0066757267,
#               0.0022428331,
#               -0.034935422,
#               0.013153556,
#               0.01354935,
#               -0.014789505,
#               -0.003809518,
#               -0.0055839946,
#               -0.01241474,
#               0.05166432,
#               0.015396389,
#               0.023483781,
#               -0.0026171883,
#               -0.014776312,
#               0.0037765352,
#               0.0025842055,
#               0.018417617,
#               -0.0019839178,
#               -0.024895446,
#               -0.004393314,
#               -0.018615514,
#               -0.003230669,
#               0.023971928,
#               0.019196013,
#               0.0037006745,
#               0.0008641504,
#               -0.020647258,
#               -0.00052731315,
#               0.011774873,
#               -0.0066262526,
#               0.017863506,
#               0.010382998,
#               -0.0022230435,
#               0.00097052,
#               0.024354529,
#               0.009789307,
#               -0.00063327054,
#               -0.013450402,
#               0.025884932,
#               -0.0054751514,
#               0.0047363355,
#               0.004822091,
#               0.0017365465,
#               0.0077179843,
#               -6.78725e-05,
#               0.0010810125,
#               -0.0074805077,
#               -0.017823927,
#               0.015290844,
#               -0.01750729,
#               -0.002706242,
#               0.013041414,
#               -0.010092748,
#               -0.014037496,
#               -0.009307757,
#               -0.008595328,
#               -0.0044229985,
#               -0.013958338,
#               -0.0030228773,
#               0.025344014,
#               -0.006134808,
#               -0.0046538785,
#               -0.03905168,
#               0.034618787,
#               -0.009947624,
#               0.016042853,
#               0.014143041,
#               -0.006715306,
#               0.018404424,
#               0.0027243826,
#               -0.007526684,
#               0.0063096173,
#               0.0019525841,
#               -0.011471432,
#               -0.013384436,
#               -0.0010727668,
#               -0.012863307,
#               0.017454518,
#               0.014261779,
#               0.0075002974,
#               0.0077575636,
#               -0.008865787,
#               0.005963297,
#               -0.017071918,
#               -0.021306913,
#               0.00069222733,
#               0.008021426,
#               0.024183018,
#               0.014974209,
#               -0.017982244,
#               -0.019380717,
#               -0.002475362,
#               0.0056730486,
#               -0.06079397,
#               0.020502133,
#               0.033114772,
#               0.003994222,
#               -0.035278443,
#               0.009294564,
#               -0.16697232,
#               0.012394951,
#               0.0021702708,
#               -0.020145917,
#               0.026650134,
#               0.005217885,
#               0.017243428,
#               -0.025911318,
#               -0.0007280962,
#               0.012810535,
#               0.014921436,
#               0.007526684,
#               -0.04847158,
#               -0.022335978,
#               -0.0049441275,
#               -0.022547068,
#               -0.0061512995,
#               0.0049804086,
#               0.031452436,
#               0.015000595,
#               0.017599642,
#               0.0297901,
#               -0.014459677,
#               -0.001904759,
#               -0.0033197228,
#               0.040370993,
#               0.007876302,
#               0.0021785165,
#               0.012520285,
#               -0.0012855062,
#               -0.013971531,
#               0.0029107356,
#               -0.0011098725,
#               0.002415993,
#               0.0015864746,
#               -0.0049111447,
#               -0.0026089426,
#               -0.0128303245,
#               -0.027784744,
#               0.0038523956,
#               0.003044316,
#               0.033325862,
#               0.03150521,
#               -0.026518203,
#               -0.018035017,
#               0.013001835,
#               -0.006540497,
#               -0.004066784,
#               -0.00022840616,
#               -0.011458239,
#               0.0037798334,
#               -0.0070913103,
#               -0.0009606252,
#               -0.0062139668,
#               0.016715704,
#               -0.0066823233,
#               0.010501736,
#               0.014987402,
#               0.019591806,
#               0.0044427887,
#               0.0010810125,
#               -0.039711338,
#               0.02112221,
#               -0.0045681233,
#               0.015765797,
#               -0.0037798334,
#               -0.024895446,
#               0.007434332,
#               -0.017322587,
#               0.019116854,
#               -0.008700873,
#               -0.017098304,
#               0.015686639,
#               -0.007665212,
#               0.0031993354,
#               -0.0049672155,
#               -0.012599445,
#               0.034988195,
#               -0.004719844,
#               -0.008786628,
#               -0.026702907,
#               0.025357207,
#               -0.008443607,
#               -0.022098502,
#               0.020000793,
#               0.009987203,
#               -0.0021999553,
#               -0.013615316,
#               -0.011794663,
#               -0.006715306,
#               0.026241146,
#               -0.023022022,
#               0.017032338,
#               -0.00015275177,
#               0.027283404,
#               0.008410624,
#               -0.008232516,
#               0.013061204,
#               -0.0013729107,
#               -0.014235393,
#               0.0022230435,
#               -0.0049111447,
#               -0.020238271,
#               0.01047535,
#               0.045542706,
#               0.003694078,
#               0.0030030876,
#               0.0124873025,
#               0.011029461,
#               0.016003273,
#               -0.015488741,
#               0.0023648695,
#               0.011583573,
#               0.0006662533,
#               -0.013133766,
#               0.041241743,
#               0.0072166454,
#               -0.02310118,
#               0.026623748,
#               0.0016507911,
#               0.038523957,
#               0.022573454,
#               -0.008364448,
#               0.017969051,
#               -0.008661293,
#               -0.013984724,
#               -0.09963456,
#               0.0057423124,
#               0.014037496,
#               0.036122806,
#               0.0064184605,
#               0.051822636,
#               0.011689118,
#               0.022441523,
#               -0.002742523,
#               0.01712469,
#               -0.005468555,
#               -0.01401111,
#               -0.019763317,
#               -0.009439688,
#               0.026333498,
#               0.0010142223,
#               -0.027969448,
#               -0.026135601,
#               0.0016903705,
#               0.0270987,
#               9.8896984e-05,
#               -0.01243453,
#               -0.00024221772,
#               -0.017678801,
#               -0.021465233,
#               -0.017916279,
#               -0.019552227,
#               0.026636941,
#               0.022270013,
#               0.0076520187,
#               -0.010660053,
#               -0.008575538,
#               0.0039876252,
#               -0.016267136,
#               0.0074541215,
#               -0.007084714,
#               -0.038761433,
#               0.00072026276,
#               0.03282452,
#               -0.008681083,
#               0.012744569,
#               0.009406705,
#               0.0049903034,
#               -0.00064110395,
#               0.0065833745,
#               -0.0016829494,
#               -0.023628905,
#               0.010415981,
#               0.016596965,
#               -0.019169627,
#               -0.013668088,
#               -0.014829084,
#               0.004818793,
#               -0.012480706,
#               0.04388037,
#               -0.012810535,
#               0.02654459,
#               0.025818966,
#               -0.017929472,
#               0.0038359042,
#               0.00017924112,
#               -0.010673246,
#               0.023444202,
#               0.02448646,
#               0.010567701,
#               0.013562543,
#               -0.004178926,
#               -0.021715902,
#               0.016939986,
#               -0.016544193,
#               0.011992561,
#               0.01943349,
#               -0.043853983,
#               -0.008601924,
#               -0.0140506895,
#               0.0009012561,
#               -0.031689912,
#               -0.009677165,
#               -2.121982e-05,
#               -0.019539034,
#               -0.0013712615,
#               -0.010956899,
#               -0.01354935,
#               -0.0018420916,
#               0.019459875,
#               0.008463397,
#               -0.00025582314,
#               -0.028787423,
#               0.006576778,
#               -0.027204245,
#               -0.0029668063,
#               0.0017464414,
#               0.015739411,
#               -0.021227755,
#               0.0013976478,
#               0.015501934,
#               0.013734054,
#               -0.0074211387,
#               -0.013318471,
#               -0.0099410275,
#               -0.0074871043,
#               0.0051288316,
#               -0.048497967,
#               0.01447287,
#               0.010824968,
#               -0.00091857207,
#               -0.0004601106,
#               0.013536157,
#               0.026096022,
#               -0.023694871,
#               0.006576778,
#               0.022863705,
#               -0.03274536,
#               0.03694078,
#               -0.014961015,
#               -0.018364845,
#               -0.018127369,
#               -0.021597164,
#               0.015726218,
#               -0.008925157,
#               0.01973693,
#               0.018364845,
#               0.007236435,
#               0.014446484,
#               0.034777105,
#               0.02335185,
#               -0.03192739,
#               0.014789505,
#               -0.025225276,
#               0.020185497,
#               -0.025766194,
#               0.024750322,
#               -0.0071045035,
#               -0.020145917,
#               0.0041492414,
#               0.015370003,
#               0.0031614052,
#               -0.015053368,
#               0.0043735243,
#               0.029526237,
#               -0.0086481,
#               0.037653208,
#               -0.009809096,
#               -0.01270499,
#               -0.017362166,
#               0.012170668,
#               -0.010686439,
#               0.02406428,
#               -0.03665053,
#               0.02296925,
#               0.021386072,
#               -0.016399067,
#               0.021702709,
#               0.04068763,
#               -0.0036544986,
#               -0.0032801433,
#               0.0028629105,
#               -0.0075662634,
#               0.010785389,
#               -0.0018849693,
#               0.021518005,
#               -0.02162355,
#               0.013212926,
#               -0.008133568,
#               0.0016285277,
#               -0.0128896935,
#               0.016227556,
#               -0.022375558,
#               -0.009835483,
#               -0.006006175,
#               0.01641226,
#               -0.028127765,
#               -0.039104454,
#               0.0017052128,
#               -0.010686439,
#               0.0076981946,
#               -0.013100783,
#               -0.013747247,
#               -0.0016516157,
#               -0.012955659,
#               -0.038260095,
#               0.022230433,
#               0.01645184,
#               -0.011675925,
#               -0.008522766,
#               0.009452881,
#               0.02292967,
#               -0.0115044145,
#               0.0134108225,
#               0.047653604,
#               0.0041888207,
#               0.016095625,
#               0.010851354,
#               0.0018882676,
#               -0.0017678802,
#               -0.00072356104,
#               -0.0037402539,
#               -0.014881857,
#               -0.023839995,
#               -0.0035984279,
#               0.015000595,
#               0.009175826,
#               -0.010330225,
#               -0.006230458,
#               0.0031713,
#               -0.000121521145,
#               -0.015422775,
#               0.0035984279,
#               -0.014103462,
#               -0.0541974,
#               -0.02406428,
#               0.022032537,
#               -0.006820851,
#               0.01779754,
#               0.022665808,
#               0.009914641,
#               -0.0040832753,
#               -0.0053827995,
#               0.0074211387,
#               0.0043372433,
#               -0.014499256,
#               0.02823331,
#               0.013958338,
#               0.028629104,
#               0.021913799,
#               -0.0064514433,
#               0.015343617,
#               -0.020053566,
#               0.031742685,
#               -0.0034137238,
#               0.0013481736,
#               0.013747247,
#               0.015251265,
#               0.028180538,
#               -0.009518848,
#               -0.0035060758,
#               -0.0012970502,
#               -2.1438846e-05,
#               -0.0025281347,
#               0.031083027,
#               -0.032982837,
#               0.049025692,
#               0.011332904,
#               -0.019275172,
#               -0.0001760459,
#               0.0024110456,
#               0.026359886,
#               0.004238295,
#               0.0027672602,
#               -0.015330424,
#               -0.007632229,
#               0.009921238,
#               -0.015831763,
#               0.034829877,
#               -0.016016467,
#               -0.026096022,
#               -0.009822289,
#               -0.0109239165,
#               0.024763515,
#               0.022863705,
#               -0.019090468,
#               0.028761035,
#               -0.014393711,
#               0.014195814,
#               0.00040115378,
#               -0.0028513665,
#               -0.011979368,
#               0.03617558,
#               -0.016887214,
#               -0.005313535,
#               -0.016359488,
#               0.02823331,
#               0.019961214,
#               -0.023760837,
#               -0.015277651,
#               0.0014520695,
#               -0.012540075,
#               -0.007586053,
#               -0.0068736235,
#               0.021544391,
#               0.027784744,
#               -0.0004258909,
#               0.013496578,
#               -0.016992759,
#               0.03356334,
#               0.017652415,
#               -0.00734198,
#               0.0004922689,
#               -0.008681083,
#               -0.04211249
#             ]
#           },
#           "answer": "Shinto",
#           "question": "Compiled in 712, the Kojiki, \"Records of Ancient Matters\", is one of this religion's oldest texts"
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# These vector representations come from deep learning models that are similar to those that power LLMs. They capture meaning, and are called vector "embeddings".

# %% [markdown]
# ### Generative search

# %% [markdown]
# A generative search transforms your data at retrieval time.

# %%
response = (
    client.query
    .get("Question", ["question", "answer"])
    .with_limit(3)
    .with_near_text({"concepts": ["history"]})
    .with_generate(
        single_prompt="write a tweet with emojis explaining the {question} and {answer}"
    )
    .do()
)

jprint(response)
# Out:
# {
#   "data": {
#     "Get": {
#       "Question": [
#         {
#           "_additional": {
#             "generate": {
#               "error": null,
#               "singleResult": "\ud83d\ude8c\ud83c\udfde\ufe0f Discover the fascinating story of a bus company that started in Hibbing, Minn. in 1914! \ud83d\ude8d\u2728 The museum takes you on a journey through time, showcasing Hupmobiles and Greyhound buses \ud83d\ude90\ud83d\udc15. Don't miss this unique opportunity to explore the rich history of transportation! \ud83c\udf1f #HibbingMuseum #BusCompanyHistory #TransportationJourney"
#             }
#           },
#           "answer": "Greyhound",
#           "question": "A Hibbing, Minn. museum traces the history of this bus company founded there in 1914 using Hupmobiles"
#         },
#         {
#           "_additional": {
#             "generate": {
#               "error": null,
#               "singleResult": "\ud83c\udfa8 Did you know? The Rijksmuseum, \ud83c\uddf3\ud83c\uddf1 Netherlands' national art museum, traces its roots back to 1808 when Louis Bonaparte established its precursor! \ud83c\udfdb\ufe0f It's a treasure trove of Dutch art and history, showcasing masterpieces that will leave you in awe. \ud83d\uddbc\ufe0f Don't miss this cultural gem when you visit Amsterdam! \u2728 #Rijksmuseum #DutchArt #History"
#             }
#           },
#           "answer": "The Rijksmuseum",
#           "question": "This Dutch national art museum had its origins in one founded by Louis Bonaparte in 1808"
#         },
#         {
#           "_additional": {
#             "generate": {
#               "error": null,
#               "singleResult": "\ud83d\udcda The Kojiki, \"Records of Ancient Matters,\" \ud83c\udfef compiled in 712, is a treasure trove of knowledge for the Shinto religion! \ud83c\udf38\ud83d\ude4f This ancient text holds immense significance as one of the oldest records, shedding light on the beliefs and traditions of Shinto. \ud83c\udf8e\u2728 #Shintoism #Kojiki #AncientWisdom"
#             }
#           },
#           "answer": "Shinto",
#           "question": "Compiled in 712, the Kojiki, \"Records of Ancient Matters\", is one of this religion's oldest texts"
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# You can see here ⬆️ that each object has been transformed by the LLM based on our prompt.

# %% [markdown]
# #### LLMs are linguistically very flexible

# %%
response = (
    client.query
    .get("Question", ["question", "answer"])
    .with_limit(3)
    .with_near_text({"concepts": ["history"]})
    .with_generate(
        single_prompt="translate the {question} into French"
    )
    .do()
)

jprint(response)
# Out:
# {
#   "data": {
#     "Get": {
#       "Question": [
#         {
#           "_additional": {
#             "generate": {
#               "error": null,
#               "singleResult": "Un mus\u00e9e \u00e0 Hibbing, dans le Minnesota, retrace l'histoire de cette compagnie de bus fond\u00e9e en 1914 en utilisant des Hupmobiles."
#             }
#           },
#           "answer": "Greyhound",
#           "question": "A Hibbing, Minn. museum traces the history of this bus company founded there in 1914 using Hupmobiles"
#         },
#         {
#           "_additional": {
#             "generate": {
#               "error": null,
#               "singleResult": "Ce mus\u00e9e national d'art n\u00e9erlandais trouve ses origines dans celui fond\u00e9 par Louis Bonaparte en 1808."
#             }
#           },
#           "answer": "The Rijksmuseum",
#           "question": "This Dutch national art museum had its origins in one founded by Louis Bonaparte in 1808"
#         },
#         {
#           "_additional": {
#             "generate": {
#               "error": null,
#               "singleResult": "Compil\u00e9 en 712, le Kojiki, \"Chroniques des faits anciens\", est l'un des plus anciens textes de cette religion."
#             }
#           },
#           "answer": "Shinto",
#           "question": "Compiled in 712, the Kojiki, \"Records of Ancient Matters\", is one of this religion's oldest texts"
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# In fact, this LLM is multi-lingual!

# %% [markdown]
# #### Generative search - Grouped task

# %% [markdown]
# You can also send groups of results to the LLM with Weaviate.

# %%
response = (
    client.query
    .get("Question", ["question", "answer"])
    .with_limit(3)
    .with_near_text({"concepts": ["history"]})
    .with_generate(
        grouped_task="write a short poem about these facts"
    )
    .do()
)

jprint(response)
# Out:
# {
#   "data": {
#     "Get": {
#       "Question": [
#         {
#           "_additional": {
#             "generate": {
#               "error": null,
#               "groupedResult": "In Hibbing, a town so grand,\nA bus company took its stand.\nGreyhound, born in 1914,\nUsing Hupmobiles, its history gleamed.\n\nIn the land of tulips and canals,\nThe Rijksmuseum proudly stands tall.\nOriginating from Bonaparte's decree,\nA Dutch national art museum, for all to see.\n\nCenturies ago, in ancient Japan,\nShinto's roots began to span.\nThe Kojiki, a sacred script,\nRecords of Ancient Matters, tightly gripped.\n\nThrough time and space, these facts unfold,\nStories of history, precious and bold.\nFrom Greyhound's humble start,\nTo Rijksmuseum's artistic heart.\n\nAnd Shinto's ancient wisdom, so divine,\nThese facts intertwine, like a sacred shrine.\nLet us cherish the past, embrace its lore,\nFor knowledge and beauty, forevermore."
#             }
#           },
#           "answer": "Greyhound",
#           "question": "A Hibbing, Minn. museum traces the history of this bus company founded there in 1914 using Hupmobiles"
#         },
#         {
#           "_additional": {
#             "generate": null
#           },
#           "answer": "The Rijksmuseum",
#           "question": "This Dutch national art museum had its origins in one founded by Louis Bonaparte in 1808"
#         },
#         {
#           "_additional": {
#             "generate": null
#           },
#           "answer": "Shinto",
#           "question": "Compiled in 712, the Kojiki, \"Records of Ancient Matters\", is one of this religion's oldest texts"
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# The output for a grouped task is contained in the first response object.
#
# So let's take a closer look at that one :)

# %%
print(response["data"]["Get"]["Question"][0]["_additional"]["generate"]["groupedResult"])
# Out:
# In Hibbing, a town so grand,
# A bus company took its stand.
# Greyhound, born in 1914,
# Using Hupmobiles, its history gleamed.
#
# In the land of tulips and canals,
# The Rijksmuseum proudly stands tall.
# Originating from Bonaparte's decree,
# A Dutch national art museum, for all to see.
#
# Centuries ago, in ancient Japan,
# Shinto's roots began to span.
# The Kojiki, a sacred script,
# Records of Ancient Matters, tightly gripped.
#
# Through time and space, these facts unfold,
# Stories of history, precious and bold.
# From Greyhound's humble start,
# To Rijksmuseum's artistic heart.
#
# And Shinto's ancient wisdom, so divine,
# These facts intertwine, like a sacred shrine.
# Let us cherish the past, embrace its lore,
# For knowledge and beauty, forevermore.

# %% [markdown]
# Look how far we've got in a short time - we can do much more than that!
#
# Here's something I prepared earlier.

# %% [markdown]
# ## What more can we do with Weaviate?

# %% [markdown]
# Here is a demo instance that you can connect to and try out.
#
# Like many of our production clusters, we have a read-only API key set up that you can use.

# %%
import os

api_headers = {
    "X-OpenAI-Api-Key": os.environ["OPENAI_APIKEY"],
}

# Instantiate the client with the auth config
client = weaviate.Client(
    url="https://edu-demo.weaviate.network",
    auth_client_secret=weaviate.AuthApiKey(
        api_key="learn-weaviate"
    ),
    additional_headers=api_headers
)

# %% [markdown]
# This instance is populated with the first two chapters of the "Pro Git" book.

# %%
response = (
    client.query
    .get("GitBookChunk", ["chunk"])
    .with_limit(3)
    .with_near_text({"concepts": ["history of git"]})
    .with_generate(
        grouped_task="write a cute short story for children about this topic, use emojis for cuteness"
    )
    .do()
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <cell line: 12>()
#       1 response = (
#       2     client.query
#       3     .get("GitBookChunk", ["chunk"])
#    (...)
#       9     .do()
#      10 )
# ---> 12 print(response["data"]["Get"]["Question"][0]["_additional"]["generate"]["groupedResult"])
#
# KeyError: 'Question'

# %% [markdown]
# Using Weaviate, we can talk to this book!

# %% [markdown]
# Let's see what the book says about ways of undoing commits.

# %%
print(response["data"]["Get"]["GitBookChunk"][0]["_additional"]["generate"]["groupedResult"])
# Out:
# 📚 Once upon a time, in a land called Linux 🐧, there was a little kernel named Git. It had a big dream of making things easier for everyone. But Git's journey wasn't always smooth sailing. It started with a bit of creative destruction and fiery controversy. 🔥
#
# In the early years, changes to the software were passed around as patches and archived files. But then, in 2002, a new tool called BitKeeper came into the picture. It was like a shiny treasure for the Linux kernel project. 🌟
#
# However, as time went on, the relationship between the Linux community and BitKeeper broke down. The tool's free-of-charge status was taken away, leaving the Linux developers in a tough spot. 😔
#
# But fear not, for a hero named Linus Torvalds stepped forward. He was the creator of Linux and had a brilliant idea. Linus and the Linux development community decided to create their own tool based on the lessons they learned from BitKeeper. 🌈
#
# They wanted this new tool, Git, to be fast ⚡, simple 🌟, and able to handle thousands of parallel branches. It had to be fully distributed and efficient for large projects like the Linux kernel. 🚀
#
# Since its birth in 2005, Git has grown and evolved. It became easy to use and retained its initial qualities. It was like a cute little creature that everyone loved. 🐱
#
# Git was amazingly fast, efficient with large projects, and had an incredible branching system. It made non-linear development a breeze. 🌿
#
# But that's not all! Git had another magical power. Most of its operations were local, meaning you didn't need to rely on a network. It was like having a superpower of speed! ⚡
#
# You could browse the project's history instantly, without waiting for a server. You could even see the changes between different versions of a file without needing a remote server. It was like having the project's history at your fingertips. 📜
#
# And the best part? You could work offline or off VPN! Whether you were on an airplane ✈️ or at home without a stable connection, Git allowed you to commit your changes locally. You could keep working until you found a network connection to upload your progress. It was a dream come true for developers. 💻
#
# Other systems couldn't compare. In Perforce, you couldn't do much without a server connection. In Subversion and CVS, you could edit files but couldn't commit changes without a database connection. Git made a big difference in the lives of developers. 🌟
#
# And so, Git became a beloved tool in the world of software development. It brought joy and efficiency to all who used it. The end. 🌈🐱⚡️📜💻🌟

# %% [markdown]
# Take a look at the results as we've done before

# %% [markdown]
# And the information that this is based on:

# %% [markdown]
# You can do strange and wonderful things - like this:

# %% [markdown]
# And a lot more.
#
# Weaviate makes it easy for you to work with your data and these AI models, at scale. As a vector database, we deal with data stores with 10s or 100s of M objects!
